# %%
import pandas as pd
reviews_gsm=pd.read_csv('stg_reviews_gsm_all_new.csv')
reviews_reddit=pd.read_csv('stg_reviews_reddit_new.csv')

# %%
reviews_reddit
pd.set_option('display.max_colwidth', None)

# %%
reviews_reddit
# Out:
#       Unnamed: 0  \
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 7817        7870
# 7818        7871
# 7819        7872
# 7820        7873
# 7821        7874
#
#                                                                               Post Title  \
# 0                                                        Samsung Galaxy S21 FE 5G review
# 1                                                        Samsung Galaxy S21 FE 5G review
# 2                                                        Samsung Galaxy S21 FE 5G review
# 3                                                        Samsung Galaxy S21 FE 5G review
# 4                                                        Samsung Galaxy S21 FE 5G review
# ...                                                                                  ...
# 7817                                          I cannot download Ark on Xiaomi Poco f5...
# ...

# %%
import openai
openai.api_key="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"
model='text-davinci-003'
review='The Dimensity 7200 Ultra is an amazing one that clocks up speed up to 2 GHz and possesses great video rendering capability with the advanced Arm Mali GPU unit. Performance cores that are associated with the octa-core unit and the AI-based image enhancement feature are commendable and beneficial.'
response = openai.Completion.create(
    engine="text-davinci-003",
    prompt=(f"Sentiment analysis of the following text: '{review}'\n\nSentiment score: "),
    temperature=0,
    max_tokens=10
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# c:\Users\lenovo\Desktop\SE_Factory\fsd_tech_product_analyzer\openai_test.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/SE_Factory/fsd_tech_product_analyzer/openai_test.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> model='text-davinci-003'
#       <a href='vscode-notebook-cell:/c%3A/Users/lenovo/Desktop/SE_Factory/fsd_tech_product_analyzer/openai_test.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> review='The Dimensity 7200 Ultra is an amazing one that clocks up speed up to 2 GHz and possesses great video rendering capability with the advanced Arm Mali GPU unit. Performance cores that are associated with the octa-core unit and the AI-based image enhancement feature are commendable and beneficial.'
# ...
